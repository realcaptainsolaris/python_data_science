# %% [markdown]
# # Pandas Query Language
# In diesem Notebook werden die Funktionalitäten der **Pandas Query Language** anhand des Datensatzes `netflix_titles.csv` demonstriert. Mit der Methode `query()` können wir komplexe Filterungen und Bedingungen auf Pandas-Datenrahmen anwenden.

# %%
# Bibliotheken importieren
import pandas as pd

# Netflix-Datensatz laden
df = pd.read_csv('netflix_titles.csv')

# Vorschau auf die ersten Zeilen des Datensatzes
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# 4    January 1, 2020          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %% [markdown]
# ## 1. Grundlagen von `query()`
# Die Methode `query()` erlaubt es, Daten auf Basis einer Abfrage zu filtern. Die Syntax ähnelt SQL, wobei Bedingungen als String übergeben werden.

# %%
# Filme filtern, die nach 2015 veröffentlicht wurden
filtered = df.query('release_year > 2015')
filtered.head()
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
# 5      s6  TV Show    46        Serdar Akar
# 6      s7    Movie   122    Yasir Al Yasiri
# 8      s9    Movie   706      Shravan Kumar
#
#                                                 cast country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey
# 6  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...   Egypt
# 8  Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 5       July 1, 2017          2016  TV-MA   1 Season
# 6       June 1, 2020          2019  TV-MA     95 min
# 8      April 1, 2019          2019  TV-14    118 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 5    International TV Shows, TV Dramas, TV Mysteries
# 6                Horror Movies, International Movies
# 8                Horror Movies, International Movies
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 5  A genetics professor experiments with a treatm...
# 6  After an awful accident, a couple admitted to ...
# 8  When a doctor goes missing, his psychiatrist w...

# %% [markdown]
# ### Vergleich von Spaltenwerten
# Wir können Spaltenwerte direkt vergleichen. Beispiel: Zeige alle Filme, bei denen das Veröffentlichungsjahr vor dem Jahr des letzten Hinzufügens liegt.

# %%
# Vergleich von Spaltenwerten
df.query('release_year < date_added.str[:4]', engine='python').head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/collections/__init__.py:1015, in ChainMap.__getitem__(self, key)
#    1014         pass
# -> 1015 return self.__missing__(key)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/collections/__init__.py:1007, in ChainMap.__missing__(self, key)
#    1006 def __missing__(self, key):
# -> 1007     raise KeyError(key)
#
# KeyError: 'slice'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/scope.py:242, in Scope.resolve(self, key, is_local)
#     238 try:
#     239     # last ditch effort we look in temporaries
#     240     # these are created when parsing indexing expressions
#     241     # e.g., df[df > 0]
# --> 242     return self.temps[key]
#     243 except KeyError as err:
#
# KeyError: 'slice'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:660, in BaseExprVisitor.visit_Call(self, node, side, **kwargs)
#     659 try:
# --> 660     res = self.visit(node.func)
#     661 except UndefinedVariableError:
#     662     # Check if this is a supported function name
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:541, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     540 def visit_Name(self, node, **kwargs) -> Term:
# --> 541     return self.term_type(node.id, self.env, **kwargs)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/ops.py:91, in Term.__init__(self, name, env, side, encoding)
#      90 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91 self._value = self._resolve_name()
#      92 self.encoding = encoding
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/ops.py:115, in Term._resolve_name(self)
#     113     is_local = False
# --> 115 res = self.env.resolve(local_name, is_local=is_local)
#     116 self.update(res)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/scope.py:244, in Scope.resolve(self, key, is_local)
#     243 except KeyError as err:
# --> 244     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'slice' is not defined
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Vergleich von Spaltenwerten
# ----> 2 df.query('release_year < date_added.str[:4]', engine='python').head()
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/frame.py:4823, in DataFrame.query(self, expr, inplace, **kwargs)
#    4821 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822 kwargs["target"] = None
# -> 4823 res = self.eval(expr, **kwargs)
#    4825 try:
#    4826     result = self.loc[res]
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/frame.py:4949, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4946     kwargs["target"] = self
#    4947 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4949 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:805, in Expr.__init__(self, expr, engine, parser, env, level)
#     803 self.parser = parser
#     804 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 805 self.terms = self.parse()
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:824, in Expr.parse(self)
#     820 def parse(self):
#     821     """
#     822     Parse an expression.
#     823     """
# --> 824     return self._visitor.visit(self.expr)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:417, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     415     raise SyntaxError("only a single expression is allowed")
#     416 expr = node.body[0]
# --> 417 return self.visit(expr, **kwargs)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:420, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     419 def visit_Expr(self, node, **kwargs):
# --> 420     return self.visit(node.value, **kwargs)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:715, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     713     op = self.translate_In(ops[0])
#     714     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 715     return self.visit(binop)
#     717 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     718 left = node.left
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:531, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     530 def visit_BinOp(self, node, **kwargs):
# --> 531     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     532     left, right = self._maybe_downcast_constants(left, right)
#     533     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:453, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     451     left = self.visit(node.left, side="left")
#     452 if right is None:
# --> 453     right = self.visit(node.right, side="right")
#     454 op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     455 return op, op_class, left, right
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:574, in BaseExprVisitor.visit_Subscript(self, node, **kwargs)
#     572 value = self.visit(node.value)
#     573 slobj = self.visit(node.slice)
# --> 574 result = pd_eval(
#     575     slobj, local_dict=self.env, engine=self.engine, parser=self.parser
#     576 )
#     577 try:
#     578     # a Term instance
#     579     v = value.value[result]
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:805, in Expr.__init__(self, expr, engine, parser, env, level)
#     803 self.parser = parser
#     804 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 805 self.terms = self.parse()
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:824, in Expr.parse(self)
#     820 def parse(self):
#     821     """
#     822     Parse an expression.
#     823     """
# --> 824     return self._visitor.visit(self.expr)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:417, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     415     raise SyntaxError("only a single expression is allowed")
#     416 expr = node.body[0]
# --> 417 return self.visit(expr, **kwargs)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:420, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     419 def visit_Expr(self, node, **kwargs):
# --> 420     return self.visit(node.value, **kwargs)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/expr.py:664, in BaseExprVisitor.visit_Call(self, node, side, **kwargs)
#     661 except UndefinedVariableError:
#     662     # Check if this is a supported function name
#     663     try:
# --> 664         res = FuncNode(node.func.id)
#     665     except ValueError:
#     666         # Raise original error
#     667         raise
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/computation/ops.py:567, in FuncNode.__init__(self, name)
#     565 def __init__(self, name: str) -> None:
#     566     if name not in MATHOPS:
# --> 567         raise ValueError(f'"{name}" is not a supported function')
#     568     self.name = name
#     569     self.func = getattr(np, name)
#
# ValueError: "slice" is not a supported function

# %% [markdown]
# ## 2. Verwendung von logischen Operatoren
# Logische Operatoren wie `and`, `or` und `not` können für komplexere Abfragen verwendet werden:

# %%
# Filme oder Serien, die nach 2010 veröffentlicht wurden und im Jahr 2020 hinzugefügt wurden
filtered = df.query('release_year > 2010 and date_added.str.contains("2020", na=False)')
filtered.head()
# Out:
#    show_id     type                                title         director  \
# 0       s1  TV Show                                   3%              NaN
# 6       s7    Movie                                  122  Yasir Al Yasiri
# 14     s15    Movie                                 3022       John Suits
# 24     s25  TV Show  ​SAINT SEIYA: Knights of the Zodiac              NaN
# 26     s27  TV Show                             (Un)Well              NaN
#
#                                                  cast        country  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 6   Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
# 14  Omar Epps, Kate Walsh, Miranda Cosgrove, Angus...  United States
# 24  Bryson Baugus, Emily Neves, Blake Shepard, Pat...          Japan
# 26                                                NaN  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 6       June 1, 2020          2019  TV-MA     95 min
# 14    March 19, 2020          2019      R     91 min
# 24  January 23, 2020          2020  TV-14  2 Seasons
# 26   August 12, 2020          2020  TV-MA   1 Season
#
#                                             listed_in  \
# 0   International TV Shows, TV Dramas, TV Sci-Fi &...
# 6                 Horror Movies, International Movies
# 14    Independent Movies, Sci-Fi & Fantasy, Thrillers
# 24               Anime Series, International TV Shows
# 26                                         Reality TV
#
#                                           description
# 0   In a future where the elite inhabit an island ...
# 6   After an awful accident, a couple admitted to ...
# 14  Stranded when the Earth is suddenly destroyed ...
# 24  Seiya and the Knights of the Zodiac rise again...
# 26  This docuseries takes a deep dive into the luc...

# %% [markdown]
# ## 3. String-Operationen
# Strings können mit der `query()`-Methode und Python-Ausdrücken verarbeitet werden. Beispiel: Filtern Sie alle Titel, die das Wort 'Love' enthalten.

# %%
# Titel filtern, die das Wort 'Love' enthalten
filtered = df.query('title.str.contains("Love", case=False, na=False)')
filtered.head()
# Out:
#     show_id     type                             title               director  \
# 198    s199  TV Show  A Little Thing Called First Love                    NaN
# 199    s200  TV Show               A Love So Beautiful                    NaN
# 200    s201    Movie           A Love Song for Latasha   Sophia Nahli Allison
# 201    s202    Movie                      A Love Story  Maryo J. De los Reyes
# 223    s224    Movie                     A Secret Love            Chris Bolan
#
#                                                   cast        country  \
# 198  Lai Kuan-lin, Zhao Jinmai, Wang Runze, Chai We...          China
# 199  Kim Yo-han, So Joo-yeon, Yeo Hoi-hyun, Jeong J...    South Korea
# 200                                                NaN  United States
# 201  Maricel Soriano, Aga Muhlach, Angelica Pangani...    Philippines
# 223                                                NaN  United States
#
#              date_added  release_year rating  duration  \
# 198    October 26, 2019          2019   TV-G  1 Season
# 199   December 28, 2020          2020  TV-PG  1 Season
# 200  September 21, 2020          2020  TV-PG    20 min
# 201      March 14, 2019          2007  TV-14   117 min
# 223      April 29, 2020          2020  TV-14    83 min
#
#                                              listed_in  \
# 198  International TV Shows, Romantic TV Shows, Tee...
# 199  International TV Shows, Romantic TV Shows, TV ...
# 200                                      Documentaries
# 201      Dramas, International Movies, Romantic Movies
# 223                        Documentaries, LGBTQ Movies
#
#                                            description
# 198  A shy college student with a knack for drawing...
# 199  Love is as tough as it is sweet for a lovestru...
# 200  The killing of Latasha Harlins became a flashp...
# 201  Self-made millionaire Ian thinks he's found ha...
# 223  Amid shifting times, two women kept their deca...

# %% [markdown]
# ## 4. Kombination von Bedingungen
# Bedingungen können mit Klammern gruppiert werden, um die Abfrage zu strukturieren. Beispiel: Filtern Sie alle Serien mit einer bestimmten Dauer und einem Veröffentlichungsjahr vor 2015.

# %%
# Serien filtern mit Dauer und Jahr
filtered = df.query('(type == "TV Show") and (release_year < 2015)')
filtered.head(3)

# Alternative
# filterer = df[(df["type"] == "TV Show") & (df["release_year"] < 2015)]
# filterer
# Out:
#    show_id     type             title director  \
# 45     s46  TV Show             Şubat      NaN
# 61     s62  TV Show  12 Years Promise      NaN
# 80     s81  TV Show        20 Minutes      NaN
#
#                                                  cast      country  \
# 45  Alican Yücesoy, Melisa Sözen, Musa Uzunlar, Se...       Turkey
# 61  So-yeon Lee, Namkoong Min, Tae-im Lee, So-hui ...  South Korea
# 80  Tuba Büyüküstün, Ilker Aksum, Bülent Emin Yara...       Turkey
#
#           date_added  release_year rating  duration  \
# 45  January 17, 2017          2013  TV-MA  1 Season
# 61      May 22, 2017          2014  TV-14  1 Season
# 80   August 15, 2017          2013  TV-MA  1 Season
#
#                                             listed_in  \
# 45  Crime TV Shows, International TV Shows, TV Dramas
# 61  International TV Shows, Korean TV Shows, Roman...
# 80  Crime TV Shows, International TV Shows, TV Dramas
#
#                                           description
# 45  An orphan subjected to tests that gave him sup...
# 61  A pregnant teen is forced by her family to lea...
# 80  When his wife is convicted of murder, a horrif...

# %% [markdown]
# ## 5. Wertebereiche (`in` und `not in`)
# Die `query()`-Methode unterstützt auch Abfragen mit `in` und `not in`, um Werte in bestimmten Listen zu filtern.

# %%
# Filme und Serien aus bestimmten Ländern filtern
filtered = df.query('country in ["United States", "India"] and release_year > 2010')
filtered.head(2)

# alertantive
# filtered = df[(df['country'].isin(['United States', 'India'])) & (df['release_year'] > 2010)]
# filtered.head(2)
# Out:
#    show_id   type title       director  \
# 8       s9  Movie   706  Shravan Kumar
# 10     s11  Movie  1922   Zak Hilditch
#
#                                                  cast        country  \
# 8   Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...          India
# 10  Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...  United States
#
#           date_added  release_year rating duration  \
# 8      April 1, 2019          2019  TV-14  118 min
# 10  October 20, 2017          2017  TV-MA  103 min
#
#                               listed_in  \
# 8   Horror Movies, International Movies
# 10                    Dramas, Thrillers
#
#                                           description
# 8   When a doctor goes missing, his psychiatrist w...
# 10  A farmer pens a confession admitting to his wi...

# %% [markdown]
# ## 6. Fehlende Werte filtern
# Manchmal ist es hilfreich, nach fehlenden oder nicht fehlenden Werten zu filtern.

# %%
# Titel filtern, bei denen das Veröffentlichungsdatum fehlt
filtered = df.query('date_added.isnull()', engine='python')
filtered.head()

# %% [markdown]
# ## 7. Sortierte Abfragen
# Sortiere die gefilterten Daten nach einer bestimmten Spalte.

# %%
# Titel nach Veröffentlichungsjahr filtern und sortieren
filtered = df.query('release_year > 2000').sort_values(by='release_year', ascending=False)
filtered.head()

# %% [markdown]
# ## 8. Weitere Beispiele:
# ### Beispiel 1: Serien aus Japan mit "Anime" im Titel
# ### Beispiel 2: Filme mit einer Dauer von mehr als 120 Minuten

# %%
# Beispiel 1: Serien aus Japan mit 'Anime' im Titel
anime_shows = df.query('(type == "TV Show") and (country == "Japan") and title.str.contains("Anime", case=False, na=False)', engine='python')
anime_shows.head()

# %%
# Beispiel 2: Filme mit einer Dauer von mehr als 120 Minuten
long_movies = df.query('(type == "Movie") and (duration.str.extract("(\\d+)").astype(float) > 120)', engine='python')
long_movies.head()

# %% [markdown]
# ## Zusammenfassung
# Die `query()`-Methode in Pandas ermöglicht eine einfache und lesbare Art der Filterung von Datenrahmen, besonders bei komplexen Bedingungen. Sie unterstützt logische Operatoren, String-Operationen und sogar den Umgang mit fehlenden Werten. Probieren Sie die gezeigten Beispiele mit Ihren eigenen Daten aus!
